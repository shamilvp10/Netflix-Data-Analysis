# %% [markdown]
# # NETFLIX ANALYSIS

# %% [markdown]
# ### **PROBLEM STATEMENT**

# %% [markdown]
# With the rapid expansion of digital streaming platforms,Netflix has developed a vast library of movies and Tv shows across different countries,types and durations.However,understanding the patterns within this large dataset is essential to identify trends in content production,audience targeting and platform growth.
#
# This project aims to analayse the Netflix dataset to explore the distribution and characteristics of content available on the platform.The study focuses on identifying patterns in content type(Movies v/s Tv show),release trends over the years,country wise contributions,rating classification and duration.

# %% [markdown]
# ### **ABOUT THE DATASET**

# %% [markdown]
# - The dataset used in this project is the Netflix Dataset. It contains information about movies and TV shows on Netflix.There are about 8,807 records in the dataset.
# - It includes details like title, type, director, cast, country, release year, rating, duration, and genre.Some data was missing, so it was cleaned.
# - The duration column was also corrected. Movies are measured in minutes, and TV shows are measured in seasons.
# - This dataset helps us understand Netflix content, such as popular genres, release trends, and audience types. It is useful for learning data analysis.

# %% [markdown]
# ### **AIM OF THE PROJECT**

# %% [markdown]
# The aim of this dataset is to understand Netflix content. It helps to analyze movies and TV shows, find popular genres, study release year trends, and understand audience ratings. It is mainly used to learn data analysis and visualization.

# %% [markdown]
# --------

# %% [markdown]
# ### **Importing Libraries**

# %%
import pandas as pd   #data handling
import matplotlib.pyplot as plt   #visualization
import seaborn as sns  #visualization

# %% [markdown]
# ### **Loading Dataset**

# %%
df=pd.read_csv("netflix.csv")
print(df)
# Out:
#      show_id     type             movie name         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8785   s8803    Movie                 Zodiac    David Fincher
# 8786   s8804  TV Show            Zombie Dumb          unknown
# 8787   s8805    Movie             Zombieland  Ruben Fleischer
# 8788   s8806    Movie                   Zoom     Peter Hewitt
# 8789   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# --------

# %% [markdown]
# ### **Inspect Data**

# %%
df.head(10)
# Out:
#   show_id     type                        movie name  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                        unknown
# 2                Julien Leclercq
# 3                        unknown
# 4                        unknown
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.tail(10)
# Out:
#      show_id     type          movie name                 director  \
# 8780   s8798  TV Show           Zak Storm                  unknown
# 8781   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8782   s8800    Movie               Zenda           Avadhoot Gupte
# 8783   s8801  TV Show  Zindagi Gulzar Hai                  unknown
# 8784   s8802    Movie             Zinzana          Majid Al Ansari
# 8785   s8803    Movie              Zodiac            David Fincher
# 8786   s8804  TV Show         Zombie Dumb                  unknown
# 8787   s8805    Movie          Zombieland          Ruben Fleischer
# 8788   s8806    Movie                Zoom             Peter Hewitt
# 8789   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8780  Michael Johnston, Jessica Gee-George, Christin...
# 8781  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8782  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# ...

# %%
df.sample(20)
# Out:
#      show_id     type                               movie name  \
# 729     s730    Movie            Bling Empire - The Afterparty
# 1166   s1167  TV Show                           The Irregulars
# 3498   s3499    Movie  Do Paise Ki Dhoop Chaar Aane Ki Baarish
# 329     s330    Movie                      Catch Me If You Can
# 6013   s6018    Movie                                   5 to 7
# 3223   s3224    Movie                                 Defiance
# 3435   s3436  TV Show                     Beyblade Burst Turbo
# 5960   s5964    Movie                                   Oct-01
# 897     s898  TV Show                        Use For My Talent
# 1875   s1876  TV Show                  Do Do Sol Sol La La Sol
# 1450   s1451    Movie                        Eddie Murphy: Raw
# 4664   s4665  TV Show                         Age of Rebellion
# 3320   s3321    Movie                                   Jinxed
# 8629   s8647  TV Show                               Twirlywoos
# ...

# %% [markdown]
# -------------

# %% [markdown]
# ### **Check Column Data Type**

# %%
df.dtypes
# Out:
# show_id            object
# type               object
# movie name         object
# director           object
# cast               object
# country            object
# date_added         object
# release_year        int64
# rating             object
# duration           object
# listed_in          object
# summary            object
# rating_category    object
# dtype: object

# %% [markdown]
# ### **Display Column Names**

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'movie name', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in',
#        'summary', 'rating_category'],
#       dtype='object')

# %% [markdown]
# ### **Display Number Of Rows And Columns**

# %%
df.shape
# Out:
# (8790, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   show_id          8790 non-null   object
#  1   type             8790 non-null   object
#  2   movie name       8790 non-null   object
#  3   director         8790 non-null   object
#  4   cast             8790 non-null   object
#  5   country          8790 non-null   object
#  6   date_added       8790 non-null   object
#  7   release_year     8790 non-null   int64
#  8   rating           8790 non-null   object
#  9   duration         8790 non-null   object
#  10  listed_in        8790 non-null   object
#  11  summary          8790 non-null   object
#  12  rating_category  8790 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 892.9+ KB

# %% [markdown]
# - total 12 columns
# - memory usage: 825.8+ KB
# - missing values(director)=2634
# - missing values(cast)=825
# - missing values(country):831
# - missing values(data_added):10
# - missing values(ratings):4
# - missing values(duration):3
# - data type mistakes(duration):duration is not object,it is int64

# %% [markdown]
# ----------------

# %% [markdown]
# ## selecting columns

# %%
df["type"]
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8785      Movie
# 8786    TV Show
# 8787      Movie
# 8788      Movie
# 8789      Movie
# Name: type, Length: 8790, dtype: object

# %%
df["duration"]
# Out:
# 0          90 min
# 1       2 Seasons
# 2        1 Season
# 3        1 Season
# 4       2 Seasons
#           ...
# 8785      158 min
# 8786    2 Seasons
# 8787       88 min
# 8788       88 min
# 8789      111 min
# Name: duration, Length: 8790, dtype: object

# %%
df["rating"]
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
#         ...
# 8785        R
# 8786    TV-Y7
# 8787        R
# 8788       PG
# 8789    TV-14
# Name: rating, Length: 8790, dtype: object

# %%
df["country"]
# Out:
# 0       United States
# 1        South Africa
# 2             unknown
# 3             unknown
# 4               India
#             ...
# 8785    United States
# 8786          unknown
# 8787    United States
# 8788    United States
# 8789            India
# Name: country, Length: 8790, dtype: object

# %% [markdown]
# ## **Selecting Multiple Columns**

# %%
df[["type","country"]]
# Out:
#          type        country
# 0       Movie  United States
# 1     TV Show   South Africa
# 2     TV Show        unknown
# 3     TV Show        unknown
# 4     TV Show          India
# ...       ...            ...
# 8785    Movie  United States
# 8786  TV Show        unknown
# 8787    Movie  United States
# 8788    Movie  United States
# 8789    Movie          India
#
# [8790 rows x 2 columns]

# %%
new=df[["country","cast"]]

# %%
new
# Out:
#             country                                               cast
# 0     United States                                            unknown
# 1      South Africa  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2           unknown  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3           unknown                                            unknown
# 4             India  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...             ...                                                ...
# 8785  United States  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8786        unknown                                            unknown
# 8787  United States  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8788  United States  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8789          India  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
# [8790 rows x 2 columns]

# %% [markdown]
# ----------------

# %% [markdown]
# ## **Filter The Data**

# %%
df[df["release_year"]<1950]
# Out:
#      show_id     type                                        movie name  \
# 1331   s1332  TV Show               Five Came Back: The Reference Films
# 4250   s4251  TV Show                 Pioneers: First Women Filmmakers*
# 7208   s7220    Movie                           Know Your Enemy - Japan
# 7282   s7295    Movie                                Let There Be Light
# 7560   s7576    Movie                          Nazi Concentration Camps
# 7728   s7744  TV Show               Pioneers of African-American Cinema
# 7775   s7791    Movie                                    Prelude to War
# 7914   s7931    Movie                                        San Pietro
# 8188   s8206    Movie                              The Battle of Midway
# 8402   s8420    Movie  The Memphis Belle: A Story of a\nFlying Fortress
# 8419   s8437    Movie                                 The Negro Soldier
# 8570   s8588    Movie                                       Thunderbolt
# ...

# %%
df[df["type"]=="Movie"]
# Out:
#      show_id   type                        movie name  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8784   s8802  Movie                           Zinzana
# 8785   s8803  Movie                            Zodiac
# 8787   s8805  Movie                        Zombieland
# 8788   s8806  Movie                              Zoom
# 8789   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8784                Majid Al Ansari
# ...

# %%
df[df["country"]=="United States"]
# Out:
#      show_id     type            movie name         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 9        s10    Movie          The Starling   Theodore Melfi
# 15       s16  TV Show     Dear White People          unknown
# 27       s28    Movie             Grown Ups     Dennis Dugan
# 28       s29    Movie            Dark Skies    Scott Stewart
# ...      ...      ...                   ...              ...
# 8774   s8792    Movie           Young Adult    Jason Reitman
# 8776   s8794    Movie  Yours, Mine and Ours     Raja Gosnell
# 8785   s8803    Movie                Zodiac    David Fincher
# 8787   s8805    Movie            Zombieland  Ruben Fleischer
# 8788   s8806    Movie                  Zoom     Peter Hewitt
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# ...

# %%
df[df["director"]=="Peter Hewitt"]
# Out:
#      show_id   type movie name      director  \
# 8788   s8806  Movie       Zoom  Peter Hewitt
#
#                                                    cast        country  \
# 8788  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
#
#       date_added  release_year rating duration  \
# 8788  2020-01-11          2006     PG   88 min
#
#                                listed_in  \
# 8788  Children & Family Movies, Comedies
#
#                                                 summary rating_category
# 8788  Dragged from civilian life, a former superhero...          Family

# %%
df[df["release_year"]>2000]
# Out:
#      show_id     type             movie name         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8785   s8803    Movie                 Zodiac    David Fincher
# 8786   s8804  TV Show            Zombie Dumb          unknown
# 8787   s8805    Movie             Zombieland  Ruben Fleischer
# 8788   s8806    Movie                   Zoom     Peter Hewitt
# 8789   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df[df["listed_in"]=="Dramas"]
# Out:
#      show_id   type           movie name             director  \
# 112     s113  Movie                Worth       Sara Colangelo
# 129     s130  Movie   An Unfinished Life      Lasse Hallström
# 142     s143  Movie      Freedom Writers  Richard LaGravenese
# 162     s163  Movie             Marshall      Reginald Hudlin
# 329     s330  Movie  Catch Me If You Can     Steven Spielberg
# ...      ...    ...                  ...                  ...
# 8657   s8675  Movie      Viceroy's House      Gurinder Chadha
# 8658   s8676  Movie               Victor    Brandon Dickerson
# 8668   s8686  Movie                  VS.             Ed Lilly
# 8674   s8692  Movie            Wakefield        Robin Swicord
# 8679   s8697  Movie            War Horse     Steven Spielberg
#
#                                                    cast  \
# 112   Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# ...

# %% [markdown]
# ## Filter with multiple condition

# %%
df[(df["country"]=="India")&(df["release_year"]<2000)]
# Out:
#      show_id   type                      movie name         director  \
# 24       s25  Movie                           Jeans       S. Shankar
# 114     s115  Movie                          Anjaam     Rahul Rawail
# 253     s254  Movie                          Bombay      Mani Ratnam
# 542     s543  Movie                           Ujala    Naresh Saigal
# 1441   s1442  Movie                   Hello Brother      Sohail Khan
# ...      ...    ...                             ...              ...
# 8120   s8137  Movie                           Swami  Basu Chatterjee
# 8128   s8145  Movie                            Taal     Subhash Ghai
# 8315   s8333  Movie               The Great Gambler   Shakti Samanta
# 8611   s8629  Movie  Trikal (Past, Present, Future)    Shyam Benegal
# 8612   s8630  Movie                        Trimurti      Mukul Anand
#
#                                                    cast country  date_added  \
# ...

# %% [markdown]
# ## **Selecting Rows(iloc method)**

# %%
df.iloc[150]
# Out:
# show_id                                                         s151
# type                                                           Movie
# movie name                                               In Too Deep
# director                                               Michael Rymer
# cast               Omar Epps, LL Cool J, Nia Long, Stanley Tucci,...
# country                                                United States
# date_added                                                2021-09-01
# release_year                                                    1999
# rating                                                             R
# duration                                                      97 min
# listed_in                                                  Thrillers
# summary            Rookie cop Jeffrey Cole poses as a drug dealer...
# rating_category                                                Adult
# Name: 150, dtype: object

# %%
df.iloc[100:200]
# Out:
#     show_id     type                                movie name  \
# 100    s101  TV Show                   Tobot Galaxy Detectives
# 101    s102    Movie                    Untold: Breaking Point
# 102    s103  TV Show  Countdown: Inspiration4 Mission to Space
# 103    s104    Movie                            Shadow Parties
# 104    s105  TV Show                       Tayo the Little Bus
# ..      ...      ...                                       ...
# 195    s196    Movie           EMI: Liya Hai To Chukana Padega
# 196    s197    Movie                             He's All That
# 197    s198  TV Show                              I Heart Arlo
# 198    s199  TV Show      King of Boys: The Return of the King
# 199    s200    Movie                                Koi Aap Sa
#
#                      director  \
# 100                   unknown
# 101  Chapman Way, Maclain Way
# 102               Jason Hehir
# 103                Yemi Amodu
# 104                   unknown
# ...

# %% [markdown]
# ## **Selecting Rows(loc method)**

# %%
df.loc[500,"type"]
# Out:
# 'Movie'

# %% [markdown]
# -------------

# %% [markdown]
# ## **Rename Column**

# %%
df.rename(columns={"title":"movie name","description":"summary"},inplace="true")

# %%
df.iloc[100:105]
# Out:
#     show_id     type                                movie name  \
# 100    s101  TV Show                   Tobot Galaxy Detectives
# 101    s102    Movie                    Untold: Breaking Point
# 102    s103  TV Show  Countdown: Inspiration4 Mission to Space
# 103    s104    Movie                            Shadow Parties
# 104    s105  TV Show                       Tayo the Little Bus
#
#                      director  \
# 100                   unknown
# 101  Chapman Way, Maclain Way
# 102               Jason Hehir
# 103                Yemi Amodu
# 104                   unknown
#
#                                                   cast        country  \
# 100  Austin Abell, Travis Turner, Cole Howard, Anna...        unknown
# 101                                            unknown  United States
# 102                                            unknown        unknown
# 103  Jide Kosoko, Omotola Jalade-Ekeinde, Yemi Blaq...        unknown
# ...

# %% [markdown]
# ## **Value Count**

# %%
df["type"].value_counts()
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
df["country"].value_counts()
# Out:
# country
# United States                             2809
# India                                      972
# unknown                                    829
# United Kingdom                             418
# Japan                                      243
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: count, Length: 749, dtype: int64

# %% [markdown]
# ------------------

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# ### **Clean Numerical Columns With Characters**

# %%
# df["engine"]=pd.to_numeric(
#    .astype(str)
#    .str.replace(r'[^0]','',regax=True)
#    .replace('',None),
#    error='coerce'
#)

# %% [markdown]
# #### **Parse Date_added As Datetime**

# %%
df["date_added"]=pd.to_datetime(df["date_added"],
                                errors="coerce")

# %%
df.dtypes
# Out:
# show_id                    object
# type                       object
# movie name                 object
# director                   object
# cast                       object
# country                    object
# date_added         datetime64[ns]
# release_year                int64
# rating                     object
# duration                   object
# listed_in                  object
# summary                    object
# rating_category            object
# dtype: object

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %%
import pandas as pd

def categorize_rating(rating):
    if pd.isna(rating):
        return "Unknown"
    
    rating = str(rating).strip()

    # Handle wrong entries like durations
    if "min" in rating:
        return "Unknown"
    
    # Kids content
    if rating in ["TV-Y", "TV-Y7", "TV-Y7-FV", "G"]:
        return "Kids"
    
    # Family / General
    elif rating in ["TV-G", "PG", "TV-PG"]:
        return "Family"
    
    # Teens
    elif rating in ["PG-13", "TV-14"]:
        return "Teen"
    
    # Adults
    elif rating in ["R", "TV-MA", "NC-17"]:
        return "Adult"
    
    # Not Rated / Others
    elif rating in ["NR", "UR"]:
        return "Unrated"
    
    else:
        return "Unrated"

# %%
df["rating_category"] = df["rating"].apply(categorize_rating)

# %%
print(df["rating_category"].value_counts())
# Out:
# rating_category
# Adult      4007
# Teen       2647
# Family     1368
# Kids        686
# Unrated      82
# Name: count, dtype: int64

# %%
df
# Out:
#      show_id     type             movie name         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8785   s8803    Movie                 Zodiac    David Fincher
# 8786   s8804  TV Show            Zombie Dumb          unknown
# 8787   s8805    Movie             Zombieland  Ruben Fleischer
# 8788   s8806    Movie                   Zoom     Peter Hewitt
# 8789   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   show_id          8790 non-null   object
#  1   type             8790 non-null   object
#  2   movie name       8790 non-null   object
#  3   director         8790 non-null   object
#  4   cast             8790 non-null   object
#  5   country          8790 non-null   object
#  6   date_added       8790 non-null   datetime64[ns]
#  7   release_year     8790 non-null   int64
#  8   rating           8790 non-null   object
#  9   duration         8790 non-null   object
#  10  listed_in        8790 non-null   object
#  11  summary          8790 non-null   object
#  12  rating_category  8790 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 892.9+ KB

# %% [markdown]
# ### **Handling Missing Values**

# %%
df.isnull()
# Out:
#       show_id   type  movie name  director   cast  country  date_added  \
# 0       False  False       False     False  False    False       False
# 1       False  False       False     False  False    False       False
# 2       False  False       False     False  False    False       False
# 3       False  False       False     False  False    False       False
# 4       False  False       False     False  False    False       False
# ...       ...    ...         ...       ...    ...      ...         ...
# 8785    False  False       False     False  False    False       False
# 8786    False  False       False     False  False    False       False
# 8787    False  False       False     False  False    False       False
# 8788    False  False       False     False  False    False       False
# 8789    False  False       False     False  False    False       False
#
#       release_year  rating  duration  listed_in  summary  rating_category
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# movie name         0
# director           0
# cast               0
# country            0
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# summary            0
# rating_category    0
# dtype: int64

# %% [markdown]
# ### **How To Fill Missing Values**

# %%
df['director'].fillna("unknown",inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20392\2513338713.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['director'].fillna("unknown",inplace=True)

# %%
df['country'].fillna("unknown",inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20392\367023652.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna("unknown",inplace=True)

# %%
df['cast'].fillna("unknown",inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20392\2462058862.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cast'].fillna("unknown",inplace=True)

# %%
df.dropna(subset=["date_added","rating","duration"],inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# movie name         0
# director           0
# cast               0
# country            0
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# summary            0
# rating_category    0
# dtype: int64

# %%
df.shape
# Out:
# (8790, 13)

# %% [markdown]
# ### **Handling Duplicates**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# print("before:",df.shape)
# df=df.drop_duplicates()
# print("after:",df.shape)

# %% [markdown]
# --------------

# %% [markdown]
# ### **Ensuring Data Cleaning**

# %%
df.head(10)
# Out:
#   show_id     type                        movie name  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                        unknown
# 2                Julien Leclercq
# 3                        unknown
# 4                        unknown
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# movie name         0
# director           0
# cast               0
# country            0
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# summary            0
# rating_category    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'movie name', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in',
#        'summary', 'rating_category'],
#       dtype='object')

# %%
df.dtypes
# Out:
# show_id                    object
# type                       object
# movie name                 object
# director                   object
# cast                       object
# country                    object
# date_added         datetime64[ns]
# release_year                int64
# rating                     object
# duration                   object
# listed_in                  object
# summary                    object
# rating_category            object
# dtype: object

# %%
df.sample(10)
# Out:
#      show_id     type                    movie name          director  \
# 1763   s1764    Movie                      Piercing     Nicolas Pesce
# 5838   s5842    Movie                      Ip Man 3        Wilson Yip
# 7876   s7893  TV Show            Roonpi Secret Love           unknown
# 1097   s1098    Movie                    Coded Bias  Shalini Kantayya
# 7618   s7634    Movie             Oasis: Supersonic    Mat Whitecross
# 3086   s3087  TV Show               The Degenerates           unknown
# 8540   s8558  TV Show                 The West Wing           unknown
# 6779   s6786  TV Show              Forces of Nature           unknown
# 4114   s4115  TV Show  Barbie Dreamhouse Adventures           unknown
# 4995   s4996    Movie                  Ladies First        Uraaz Bahl
#
#                                                    cast  \
# 1763  Christopher Abbott, Mia Wasikowska, Laia Costa...
# 5838  Donnie Yen, Zhang Jin, Lynn Hung, Patrick Tam,...
# ...

# %%
df.shape
# Out:
# (8790, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   show_id          8790 non-null   object
#  1   type             8790 non-null   object
#  2   movie name       8790 non-null   object
#  3   director         8790 non-null   object
#  4   cast             8790 non-null   object
#  5   country          8790 non-null   object
#  6   date_added       8790 non-null   datetime64[ns]
#  7   release_year     8790 non-null   int64
#  8   rating           8790 non-null   object
#  9   duration         8790 non-null   object
#  10  listed_in        8790 non-null   object
#  11  summary          8790 non-null   object
#  12  rating_category  8790 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 892.9+ KB

# %% [markdown]
# ### **Filtering The Data -movie and tv show**

# %%
movies=df[df['type']=='Movie']

# %%
movies
# Out:
#      show_id   type                        movie name  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8784   s8802  Movie                           Zinzana
# 8785   s8803  Movie                            Zodiac
# 8787   s8805  Movie                        Zombieland
# 8788   s8806  Movie                              Zoom
# 8789   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8784                Majid Al Ansari
# ...

# %% [markdown]
# #### **Parase Movies As Numerical**

# %%
movies["duration"] = movies["duration"].str.replace("min"," ",regex=False)
movies["duration"] = pd.to_numeric(movies["duration"], errors="coerce")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20392\1304505552.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["duration"] = movies["duration"].str.replace("min"," ",regex=False)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20392\1304505552.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["duration"] = pd.to_numeric(movies["duration"], errors="coerce")

# %%
movies.dtypes
# Out:
# show_id                    object
# type                       object
# movie name                 object
# director                   object
# cast                       object
# country                    object
# date_added         datetime64[ns]
# release_year                int64
# rating                     object
# duration                    int64
# listed_in                  object
# summary                    object
# rating_category            object
# dtype: object

# %%
tv_shows=df[df['type']=='TV Show']

# %%
tv_shows
# Out:
#      show_id     type             movie name         director  \
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8778   s8796  TV Show        Yu-Gi-Oh! Arc-V          unknown
# 8779   s8797  TV Show             Yunus Emre          unknown
# 8780   s8798  TV Show              Zak Storm          unknown
# 8783   s8801  TV Show     Zindagi Gulzar Hai          unknown
# 8786   s8804  TV Show            Zombie Dumb          unknown
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %% [markdown]
# #### **Parase TV_show To Numeric**

# %%
tv_shows["duration"] = tv_shows["duration"].astype(str)
tv_shows["duration"] = tv_shows["duration"].str.split().str[0].astype(int)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20392\4025971363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_shows["duration"] = tv_shows["duration"].astype(str)
# C:\Users\HP\AppData\Local\Temp\ipykernel_20392\4025971363.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_shows["duration"] = tv_shows["duration"].str.split().str[0].astype(int)

# %%
tv_shows
# Out:
#      show_id     type             movie name         director  \
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8778   s8796  TV Show        Yu-Gi-Oh! Arc-V          unknown
# 8779   s8797  TV Show             Yunus Emre          unknown
# 8780   s8798  TV Show              Zak Storm          unknown
# 8783   s8801  TV Show     Zindagi Gulzar Hai          unknown
# 8786   s8804  TV Show            Zombie Dumb          unknown
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %% [markdown]
# -----------------

# %% [markdown]
# ### **Save To File**

# %%
df.to_csv("netflix_cleaned.csv",index=False)

# %%
movies.to_csv("movies.csv",index=False)

# %%
tv_shows.to_csv("tv_shows.csv",index=False)

# %% [markdown]
# ### **Load New Data**

# %%
df_new=pd.read_csv("netflix_cleaned.csv")

# %%
df_new
# Out:
#      show_id     type             movie name         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8785   s8803    Movie                 Zodiac    David Fincher
# 8786   s8804  TV Show            Zombie Dumb          unknown
# 8787   s8805    Movie             Zombieland  Ruben Fleischer
# 8788   s8806    Movie                   Zoom     Peter Hewitt
# 8789   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_new1=pd.read_csv("movies.csv")

# %%
df_new1
# Out:
#      show_id   type                        movie name  \
# 0         s1  Movie              Dick Johnson Is Dead
# 1         s7  Movie  My Little Pony: A New Generation
# 2         s8  Movie                           Sankofa
# 3        s10  Movie                      The Starling
# 4        s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 6121   s8802  Movie                           Zinzana
# 6122   s8803  Movie                            Zodiac
# 6123   s8805  Movie                        Zombieland
# 6124   s8806  Movie                              Zoom
# 6125   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 1     Robert Cullen, José Luis Ucha
# 2                      Haile Gerima
# 3                    Theodore Melfi
# 4               Christian Schwochow
# ...                             ...
# 6121                Majid Al Ansari
# ...

# %%
df_new2=pd.read_csv("tv_shows.csv")

# %%
df_new2
# Out:
#      show_id     type             movie name         director  \
# 0         s2  TV Show          Blood & Water          unknown
# 1         s3  TV Show              Ganglands  Julien Leclercq
# 2         s4  TV Show  Jailbirds New Orleans          unknown
# 3         s5  TV Show           Kota Factory          unknown
# 4         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 2659   s8796  TV Show        Yu-Gi-Oh! Arc-V          unknown
# 2660   s8797  TV Show             Yunus Emre          unknown
# 2661   s8798  TV Show              Zak Storm          unknown
# 2662   s8801  TV Show     Zindagi Gulzar Hai          unknown
# 2663   s8804  TV Show            Zombie Dumb          unknown
#
#                                                    cast  \
# 0     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 1     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %% [markdown]
# --------------------

# %% [markdown]
# ## **Summary Statistics**

# %% [markdown]
# ### **Average(mean)**

# %%
print("release_year  -",df_new["release_year"].mean())
# Out:
# release_year  - 2014.183162684869

# %% [markdown]
# ### **Median**

# %%
print("release_year  -",df_new["release_year"].median())
# Out:
# release_year  - 2017.0

# %% [markdown]
# ### **Mode**

# %%
df_new["release_year"].mode()
# Out:
# 0    2018
# Name: release_year, dtype: int64

# %%
print("release_year  -",df_new["release_year"].mode())
# Out:
# release_year  - 0    2018
# Name: release_year, dtype: int64

# %% [markdown]
# ### **Standard Deviation**

# %%
print("release_year  -",df_new["release_year"].std())
# Out:
# release_year  - 8.82546602834746

# %% [markdown]
# ###

# %%
df_new.select_dtypes(include='number').mean()
# Out:
# release_year    2014.183163
# dtype: float64

# %%
df_new.select_dtypes(include='number').median()
# Out:
# release_year    2017.0
# dtype: float64

# %%
df_new.select_dtypes(include='object').mode()
# Out:
#      show_id   type                     movie name director     cast  \
# 0         s1  Movie                         #Alive  unknown  unknown
# 1        s10    NaN  #AnneFrank - Parallel Stories      NaN      NaN
# 2       s100    NaN              #FriendButMarried      NaN      NaN
# 3      s1000    NaN            #FriendButMarried 2      NaN      NaN
# 4      s1001    NaN                          #Roxy      NaN      NaN
# ...      ...    ...                            ...      ...      ...
# 8785    s995    NaN                       忍者ハットリくん      NaN      NaN
# 8786    s996    NaN                           海的儿子      NaN      NaN
# 8787    s997    NaN                           마녀사냥      NaN      NaN
# 8788    s998    NaN                        반드시 잡는다      NaN      NaN
# 8789    s999    NaN            최강전사 미니특공대 : 영웅의 탄생      NaN      NaN
#
#             country  date_added rating  duration  \
# 0     United States  2020-01-01  TV-MA  1 Season
# ...

# %%
df_new.select_dtypes(include='number').std()
# Out:
# release_year    8.825466
# dtype: float64

# %%
df_new.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# - the data set contains 8790 entries
# - the average release year is 2014
# - the standard deviation is 8.825
# - the oldest content dates back to 1925
# - 25% of the content was released before 2013
# - The median release year is 2017
# - 75% of the content was released before 2019
# - The latest content is from 2021

# %%
df_new.describe(include='object')
# Out:
#        show_id   type            movie name director     cast        country  \
# count     8790   8790                  8790     8790     8790           8790
# unique    8790      2                  8790     4527     7679            749
# top         s1  Movie  Dick Johnson Is Dead  unknown  unknown  United States
# freq         1   6126                     1     2621      825           2809
#
#         date_added rating  duration                     listed_in  \
# count         8790   8790      8790                          8790
# unique        1713     14       220                           513
# top     2020-01-01  TV-MA  1 Season  Dramas, International Movies
# freq           110   3205      1791                           362
#
#                                                   summary rating_category
# count                                                8790            8790
# unique                                               8758               5
# ...

# %% [markdown]
# - total 8790 entries,means no missing values
# - 2 unique values are movie and tv shows,dataset is heavily movie-dominate
# - every titles are unique
# - 4527 directors are unique ,the most of them are unknown(2621)
# - 7679 cast are unique,most of them are unknown(825)
# - most content dominated by the united states
# - 110 shows were released on 01/01/2020
# - majority content TV-MA
# - drama & international movies are the majority of the listed_in
# - most target on adult audience

# %%
df_new1.describe(include='object')
# Out:
#        show_id   type            movie name director     cast        country  \
# count     6126   6126                  6126     6126     6126           6126
# unique    6126      1                  6126     4353     5444            652
# top         s1  Movie  Dick Johnson Is Dead  unknown  unknown  United States
# freq         1   6126                     1      187      475           2055
#
#         date_added rating                     listed_in  \
# count         6126   6126                          6126
# unique        1531     14                           278
# top     2020-01-01  TV-MA  Dramas, International Movies
# freq            97   2062                           362
#
#                                                   summary rating_category
# count                                                6126            6126
# unique                                               6100               5
# top     Paranormal activity at a lush, abandoned prope...           Adult
# ...

# %% [markdown]
# - Total 6126 entries,means no missing
# - only movies are  in the dstaset
# - 4353 directors are unique,187 directors are unknown
# - 475 cast are unknown
# - most of the  movies dominated by united status
# - 97 movies are released on 01/01/2020
# - majority content is TV-MA
# - dramas & international Movies are the majority of the listed_in
# - 205 movies are unique duration,152 movies are 90 min duration

# %%
df_new2.describe(include='object')
# Out:
#        show_id     type     movie name director     cast        country  \
# count     2664     2664           2664     2664     2664           2664
# unique    2664        1           2664      223     2272            197
# top         s2  TV Show  Blood & Water  unknown  unknown  United States
# freq         1     2664              1     2434      350            754
#
#         date_added rating listed_in  \
# count         2664   2664      2664
# unique        1012      9       235
# top     2021-07-06  TV-MA  Kids' TV
# freq            31   1143       219
#
#                                                   summary rating_category
# count                                                2664            2664
# unique                                               2660               5
# top     As a psychology professor faces Alzheimer's, h...           Adult
# freq                                                    2            1145

# %% [markdown]
# - total 2664 entries,means no missing
# - only tv show are in the data set
# - 223 directors are unique,2434 directors are unknown
# - 350 cast are unknown
# - most of the tv shows dominated by united states
# - 31 movies are released on 06/07/2021
# - majority content is TV-MA
# - 15 tv shows are unique,1791 tv shows are 1 season
# - kid's tv are the majority of the listed_in

# %% [markdown]
# ------------------

# %% [markdown]
# ## **Data Visualization**

# %% [markdown]
# ### **Univariate Analysis**
#   - histogram,kde,box plot - numerical
#   - count, pie - categorical
# ### **Bivariate Analysis**
#   - bar plot - category vs numerical
#   - line plot(time series) and scatter - numerical vs numerical
# ### **Multivariate Analysis**
#   - heat map - correlation
#   - pair plot - numerical

# %% [markdown]
# ### **Univariate Analysis**

# %% [markdown]
# #### **Histogram**
#
# - Distribution of continous numerical data

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(4,6))      
sns.histplot(data=df_new,x="release_year",bins=50,color="purple",kde=True)
plt.title("Distribution of Release Year")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - The histogram shows the distribution of release year
# - A huge majority of the releases happened in the last 10-15 years.
# - There are very few releases from before the year 2000.
# - The no.of releases started growing very fast after 2010.
# - 2018 and 2019 were the biggest year of releases.
# - The numbers drop suddenly after 2019
# - The distribution is strongly left-skewed
# - Most of the data is crowded on the right side (recent years)

# %%
plt.figure(figsize=(4,6))      
sns.histplot(data=df_new1,x="release_year",bins=50,color="purple",kde=True)
plt.title("Distribution of Release Year(Movies)")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - Most content is released after 2000
# - Majority of release happened in 10-15 years
# - Releases from 1940 to 1980 are very rare
# - There is a massive spike right around 2018
# - After 2018 peak,there is a quick decline in the no.of releases in leading into 2020

# %%
plt.figure(figsize=(5,6))      
sns.histplot(data=df_new2,x="release_year",bins=50,color="purple",kde=True)
plt.title("Distribution of Release Year(TV_shows)")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - Almost all tv shows were released after 2010
# - TV shows from 1940 to 2000 are extremely rare
# - 2019 has the most releases followed by a small drop in 2020
# - Majority of release happened in last 5-10 years

# %% [markdown]
# ### **Box Plot**

# %%
plt.figure(figsize=(5,4))   
sns.boxplot(data=df_new,x="release_year",color="purple")
plt.title("Distribution of Release Year")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - 50% of all releases happened between approximately 2013 and 2019
# - The vertical line in the box shows the middle value is around 2017
# - The long trail of circles to the left shows that releases before 2005 are rare and considered outliers

# %%
plt.figure(figsize=(5,4))   
sns.boxplot(data=df_new1,x="release_year",color="purple")
plt.title("Distribution of Release Year")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - Most data is concentrated in 2010–2020
# - The distribution is skewed toward recent years
# - Many older years appear as outliers
# - The median is in recent years
# - Very few entries before 2000

# %%
plt.figure(figsize=(5,4))   
sns.boxplot(data=df_new2,x="release_year",color="purple")
plt.title("Distribution of Release Year")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - Most titles are recent: the catalog is heavily weighted toward releases after 2010.
# - Movies dominate the dataset over TV shows.
# - Adult-rated content is the largest rating group.
# - Netflix content peaks around 2018–2019 and drops after 2019.
# - TV shows are usually short-run (1–3 seasons) in this dataset.
# - Older releases (pre-2000) are rare and appear as outliers.

# %% [markdown]
# ### **Count Plot**

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df_new,x="release_year",color="purple")
plt.title("Distribution of Release Year")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - Most releaes are after 2010
# - there is only very few releases before 2000
# - Release increases quickly after 2010
# - The highest releases count are in 2018–2019
# - After 2019, counts drop a bit
# - The data is right-heavy, meaning recent years dominate

# %%
plt.figure(figsize=(5,4))   
sns.countplot(data=df_new1,x="release_year",color="purple")
plt.title("Distribution of Release Year(Movies)")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - Most titles are from 2010 onward.
# - Movies far outnumber TV shows.
# - Adult-rated content is the largest group.
# - Release volume peaks around 2018–2019.

# %%
plt.figure(figsize=(5,6))   
sns.countplot(data=df_new2,x="release_year",color="purple")
plt.title("Distribution of Release Year(TV_shows)")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - Most catalog entries are recent (after 2010).
# - Movies dominate over TV shows.
# - Adult-rated content is the largest group.

# %% [markdown]
# ### **Pie Chart**

# %%
x=df_new['rating_category'].value_counts()
labels=['Adult','Teen','Family','Kids','Underated']
plt.figure(figsize=(5,4))
plt.pie(x,labels=labels,autopct='%1.1f%%')  
plt.title("Distribution of Rating category")
plt.xlabel("Rating category")
plt.show()

# %% [markdown]
# - This pie chart shows how many titles are in each rating group.
# - **Adult** is the biggest group, so most titles are for mature viewers.
# - **Teen** is the next biggest group.
# - **Family** and **Kids** are smaller, so child-friendly content is less common.
# - **Unrated** titles are very few.

# %%
x=df_new1['rating_category'].value_counts()
labels=['Adult','Teen','Family','Kids','Underated']
plt.figure(figsize=(5,4))
plt.pie(x,labels=labels,autopct='%1.1f%%')  
plt.title("Distribution of Rating category")
plt.xlabel("Rating category")
plt.show()

# %%
x=df_new2['rating_category'].value_counts()
labels=['Adult','Teen','Family','Kids','Underated']
plt.figure(figsize=(5,4))
plt.pie(x,labels=labels,autopct='%1.1f%%')  
plt.title("Distribution of Rating category")
plt.xlabel("Rating category")
plt.show()

# %% [markdown]
# ## **Bivariate Analysis**

# %% [markdown]
# #### **Bar Plot**

# %%
plt.figure(figsize=(10,5))   
sns.barplot(data=df_new1,x="rating_category",y="duration",color="purple")
plt.title("Distribution of Rating category")
plt.xlabel("Rating category")
plt.show()

# %% [markdown]
# - The bar plot shows average length for each rating group.
# - **Teen** and **Adult** categories have the longest durations.
# - **Kids** content is much shorter than other groups.

# %% [markdown]
# #### **Line Plot**

# %%
plt.figure(figsize=(5,4))   
sns.lineplot(data=df_new1,x="release_year",y=("duration"))
plt.title("Distribution of Release Year")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# * Movie lengths increased sharply from the 1940s to the mid-1960s
# * Peak average duration occurred around the 1960s
# * High variability in movie lengths during the 1960s–1980s
# * Gradual decline in duration after the 1970s
# * Modern films (2000s onward) are shorter and more consistent
# * Overall trend: rise → peak → steady decline → stabilization

# %%
plt.figure(figsize=(5,4))   
sns.lineplot(data=df_new2,x="release_year",y=("duration"))
plt.title("Distribution of Release Year")
plt.xlabel("Rellease Year")
plt.show()

# %% [markdown]
# * Values stay very low and flat until around the 1950s
# * Sharp spikes appear between the 1960s–1980s (high instability)
# * Peak occurs around the late 1970s–early 1980s
# * After 1990, values drop and fluctuate frequently
# * From 2000 onward, values stabilize at low levels
# * Overall trend: flat → volatile spikes → decline → low, stable pattern

# %% [markdown]
# #### **Scatter Plot**

# %%
plt.figure(figsize=(5,6))   
sns.scatterplot(data=df_new1,x="release_year",y=("duration"))
plt.title("Distribution of Release Year with duration")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# * Most movies cluster between ~80–150 minutes
# * After 2000, many more movies are released (denser points)
# * Wide spread in durations, but majority stay in mid-range
# * Some outliers: very short (<50 min) and very long (>200 min) films
# * Older films (pre-1970) are fewer but often longer
# * Overall: high variation, but typical movie length stays around ~100–140 minutes

# %%
plt.figure(figsize=(5,6))   
sns.scatterplot(data=df_new2,x="release_year",y=("duration"))
plt.title("Distribution of Release Year with duration")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - Most TV shows are of smaller duration(1-3 seasons)
# - The number of  releases increases very much after 2010.
# - Very long-running shows (duration above 10) are rare and appear as outliers.
# - The plot suggests Netflix content is skewed toward newer, shorter-run TV = - shows rather than long multi-season series.

# %% [markdown]
# ## **Multivariate Analysis**

# %% [markdown]
# #### **HeatMap**

# %%
df_new1_num=df_new1.select_dtypes(include='number')
df_new1_num.corr()
# Out:
#               release_year  duration
# release_year      1.000000 -0.206248
# duration         -0.206248  1.000000

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df_new1.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# - The correlation between release_year and duration is -0.21.
# - This is a weak negative relationship → as release year increases, duration tends to slightly decrease.
# - The value is close to 0, so the relationship is not strong.
# - This means newer content is only slightly shorter on average, but not by much.
# - There is no strong pattern between release year and duration.

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df_new2.corr(numeric_only=True),annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# #### **Pair Plot**

# %%
plt.figure(figsize=(6,4))
sns.pairplot(df_new1.select_dtypes(include='number'), palette='coolwarm')
# Out:
# c:\Users\HP\anaconda3\New folder\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\HP\anaconda3\New folder\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\HP\anaconda3\New folder\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\HP\anaconda3\New folder\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)

# %% [markdown]
# - The pairplot shows no strong linear relationship between release_year and   duration.
# - Points are scattered widely, so newer movies are not consistently longer or shorter.
# - Most movies cluster around typical durations, regardless of release year.
# - The trend is almost flat, confirming the weak negative correlation.

# %%
plt.figure(figsize=(6,4))
sns.pairplot(df_new2.select_dtypes(include='number'), palette='coolwarm')
# Out:
# c:\Users\HP\anaconda3\New folder\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\HP\anaconda3\New folder\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\HP\anaconda3\New folder\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\HP\anaconda3\New folder\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)

# %% [markdown]
# - most releases are from 2010 onward.
# - peak release activity is around 2018–2019.
# - Movies dominate the dataset.TV shows are fewer and mostly short-run.
# - Ratings are skewed toward adult content, with teen content second-largest.
# - TV show durations are mostly 1–3 seasons; long series are rare.
# - Release year vs duration shows only a weak negative correlation.

# %% [markdown]
# ------------

# %% [markdown]
# ### **CONCLUSION**

# %% [markdown]
# In this project, the Netflix Dataset was successfully cleaned and analyzed. Several changes were made to improve the quality of the data. Missing values in columns like director, cast, and country were handled by filling or removing them.The movies and tv shows are seperated to a file. The duration column was cleaned and converted into a proper numeric format, where movies are shown in minutes and TV shows in seasons.
#
# After cleaning, the dataset became more accurate and easy to use for analysis. The analysis showed that Netflix has more movies than TV shows, most content is released after 2010, and popular genres include drama and comedy. It also showed that content is mainly made for young and adult audiences.
#
# Overall, this project helped in understanding how to clean data, fix errors, and perform data analysis. It shows the importance of data preprocessing before doing any analysis.

# %% [markdown]
# ### **KEY INSIGHTS**

# %% [markdown]
# - Movies dominated in netflix than tv shows.
# - In the dataset 6126 Moviesand 2664 Tv shows are  there.
# - Most content dominated by United States.
# - Most of the movies and tv shows target on adult audience.
# - After cleaning the dataset ,have 8790 entries.
# - The average release year is 2014.
# - The median release year is 2017.
# - The standard deviation of release year is 8.825.
# - Most of the directors are unknown.
# - Most of the cast are unknown.
# - Most of genre are drama & international movies.
# - A huge majority of the releases happened in the last 10-15 years.
# - The no.of releases started growing very fast after 2010.
# - After 2018 peak,there is a quick decline in the no.of releases in leading into 2020.
# - long trail of circles to the left shows that releases before 2005 are rare and considered outliers.
# - The highest releases count are in 2018-2019.
# - Adult is biggest rating category,so most titles are mature viewers.
# - Teen and adult categories have the longest durations.
# - Kids content is much shorter than other group.
# - Movie length increased sharply from the 1940's to the mid 1960's.
# - Some outliers very short (<50 min) and very long (>200 min) films.
# - The correlation between release year and duration is -0.21.
# - The value is close to 0,so the relationship is not strong
# - No strong linear relationship between release year and duration
# - Tv show duration are mostly 1-3 seasons
