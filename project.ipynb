# %% [markdown]
# # NETFLIX ANALYSIS

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd   #data handling
import matplotlib.pyplot as plt   #visualization
import seaborn as sns  #visualization

# %% [markdown]
# ### Loading dataset

# %%
df=pd.read_csv("netflix.csv")
print(df)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### Inspect data

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.tail(10)
# Out:
#      show_id     type               title                 director  \
# 8797   s8798  TV Show           Zak Storm                      NaN
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb                      NaN
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# ...

# %%
df.sample(20)
# Out:
#      show_id     type                                              title  \
# 8379   s8380  TV Show                                The Lady in Dignity
# 7992   s7993    Movie                                Shahanpan Dega Deva
# 5149   s5150  TV Show                                           Man Down
# 5696   s5697    Movie                                    1000 Rupee Note
# 5377   s5378    Movie                                        To the Bone
# 1140   s1141    Movie                      Universal Soldier: The Return
# 92       s93  TV Show                                     Into the Night
# 584     s585    Movie                             Not Another Teen Movie
# 765     s766    Movie                                             Xtreme
# 7920   s7921    Movie                              Safety Not Guaranteed
# 660     s661  TV Show                                    Black Lightning
# 5824   s5825    Movie                     Interview with a Serial Killer
# ...

# %% [markdown]
# ### Check column data type

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# ### Display column names

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# ### Display no.of rows and columns

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ##### - total 12 columns
# ##### - memory usage: 825.8+ KB
# ##### - missing values(director)=2634
# ##### -missing values(cast)=825
# ##### -missing values(country):831
# ##### -missing values(data_added):10
# ##### -missing values(ratings):4
# ##### -missing values(duration):3
# ##### -data type mistakes(duration):duration is not object,it is int64

# %% [markdown]
# ## selecting columns

# %%
df["type"]
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8802      Movie
# 8803    TV Show
# 8804      Movie
# 8805      Movie
# 8806      Movie
# Name: type, Length: 8807, dtype: object

# %%
df["duration"]
# Out:
# 0          90 min
# 1       2 Seasons
# 2        1 Season
# 3        1 Season
# 4       2 Seasons
#           ...
# 8802      158 min
# 8803    2 Seasons
# 8804       88 min
# 8805       88 min
# 8806      111 min
# Name: duration, Length: 8807, dtype: object

# %%
df["rating"]
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
#         ...
# 8802        R
# 8803    TV-Y7
# 8804        R
# 8805       PG
# 8806    TV-14
# Name: rating, Length: 8807, dtype: object

# %%
df["country"]
# Out:
# 0       United States
# 1        South Africa
# 2                 NaN
# 3                 NaN
# 4               India
#             ...
# 8802    United States
# 8803              NaN
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 8807, dtype: object

# %% [markdown]
# ## selecting multiple columns

# %%
df[["type","country"]]
# Out:
#          type        country
# 0       Movie  United States
# 1     TV Show   South Africa
# 2     TV Show            NaN
# 3     TV Show            NaN
# 4     TV Show          India
# ...       ...            ...
# 8802    Movie  United States
# 8803  TV Show            NaN
# 8804    Movie  United States
# 8805    Movie  United States
# 8806    Movie          India
#
# [8807 rows x 2 columns]

# %%
new=df[["country","cast"]]

# %%
new
# Out:
#             country                                               cast
# 0     United States                                                NaN
# 1      South Africa  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2               NaN  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3               NaN                                                NaN
# 4             India  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...             ...                                                ...
# 8802  United States  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803            NaN                                                NaN
# 8804  United States  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  United States  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806          India  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
# [8807 rows x 2 columns]

# %% [markdown]
# ## filter the data

# %%
df[df["release_year"]<1950]
# Out:
#      show_id     type                                             title  \
# 1331   s1332  TV Show               Five Came Back: The Reference Films
# 4250   s4251  TV Show                 Pioneers: First Women Filmmakers*
# 7219   s7220    Movie                           Know Your Enemy - Japan
# 7294   s7295    Movie                                Let There Be Light
# 7575   s7576    Movie                          Nazi Concentration Camps
# 7743   s7744  TV Show               Pioneers of African-American Cinema
# 7790   s7791    Movie                                    Prelude to War
# 7930   s7931    Movie                                        San Pietro
# 8205   s8206    Movie                              The Battle of Midway
# 8419   s8420    Movie  The Memphis Belle: A Story of a\nFlying Fortress
# 8436   s8437    Movie                                 The Negro Soldier
# 8587   s8588    Movie                                       Thunderbolt
# ...

# %%
df[df["type"]=="Movie"]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
df[df["country"]=="United States"]
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 9        s10    Movie          The Starling   Theodore Melfi
# 15       s16  TV Show     Dear White People              NaN
# 27       s28    Movie             Grown Ups     Dennis Dugan
# 28       s29    Movie            Dark Skies    Scott Stewart
# ...      ...      ...                   ...              ...
# 8791   s8792    Movie           Young Adult    Jason Reitman
# 8793   s8794    Movie  Yours, Mine and Ours     Raja Gosnell
# 8802   s8803    Movie                Zodiac    David Fincher
# 8804   s8805    Movie            Zombieland  Ruben Fleischer
# 8805   s8806    Movie                  Zoom     Peter Hewitt
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# ...

# %%
df[df["director"]=="Peter Hewitt"]
# Out:
#      show_id   type title      director  \
# 8805   s8806  Movie  Zoom  Peter Hewitt
#
#                                                    cast        country  \
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
#
#             date_added  release_year rating duration  \
# 8805  January 11, 2020          2006     PG   88 min
#
#                                listed_in  \
# 8805  Children & Family Movies, Comedies
#
#                                             description
# 8805  Dragged from civilian life, a former superhero...

# %%
df[df["release_year"]>2000]
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df[df["listed_in"]=="Dramas"]
# Out:
#      show_id   type                title             director  \
# 112     s113  Movie                Worth       Sara Colangelo
# 129     s130  Movie   An Unfinished Life      Lasse Hallström
# 142     s143  Movie      Freedom Writers  Richard LaGravenese
# 162     s163  Movie             Marshall      Reginald Hudlin
# 329     s330  Movie  Catch Me If You Can     Steven Spielberg
# ...      ...    ...                  ...                  ...
# 8674   s8675  Movie      Viceroy's House      Gurinder Chadha
# 8675   s8676  Movie               Victor    Brandon Dickerson
# 8685   s8686  Movie                  VS.             Ed Lilly
# 8691   s8692  Movie            Wakefield        Robin Swicord
# 8696   s8697  Movie            War Horse     Steven Spielberg
#
#                                                    cast  \
# 112   Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# ...

# %% [markdown]
# ## Filter with multiple condition

# %%
df[(df["country"]=="India")&(df["release_year"]<2000)]
# Out:
#      show_id   type                           title         director  \
# 24       s25  Movie                           Jeans       S. Shankar
# 114     s115  Movie                          Anjaam     Rahul Rawail
# 253     s254  Movie                          Bombay      Mani Ratnam
# 542     s543  Movie                           Ujala    Naresh Saigal
# 1441   s1442  Movie                   Hello Brother      Sohail Khan
# ...      ...    ...                             ...              ...
# 8136   s8137  Movie                           Swami  Basu Chatterjee
# 8144   s8145  Movie                            Taal     Subhash Ghai
# 8332   s8333  Movie               The Great Gambler   Shakti Samanta
# 8628   s8629  Movie  Trikal (Past, Present, Future)    Shyam Benegal
# 8629   s8630  Movie                        Trimurti      Mukul Anand
#
#                                                    cast country  \
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# ...

# %% [markdown]
# ## selecting rows(iloc method)

# %%
df.iloc[150]
# Out:
# show_id                                                      s151
# type                                                        Movie
# title                                                 In Too Deep
# director                                            Michael Rymer
# cast            Omar Epps, LL Cool J, Nia Long, Stanley Tucci,...
# country                                             United States
# date_added                                      September 1, 2021
# release_year                                                 1999
# rating                                                          R
# duration                                                   97 min
# listed_in                                               Thrillers
# description     Rookie cop Jeffrey Cole poses as a drug dealer...
# Name: 150, dtype: object

# %%
df.iloc[100:200]
# Out:
#     show_id     type                                     title  \
# 100    s101  TV Show                   Tobot Galaxy Detectives
# 101    s102    Movie                    Untold: Breaking Point
# 102    s103  TV Show  Countdown: Inspiration4 Mission to Space
# 103    s104    Movie                            Shadow Parties
# 104    s105  TV Show                       Tayo the Little Bus
# ..      ...      ...                                       ...
# 195    s196    Movie           EMI: Liya Hai To Chukana Padega
# 196    s197    Movie                             He's All That
# 197    s198  TV Show                              I Heart Arlo
# 198    s199  TV Show      King of Boys: The Return of the King
# 199    s200    Movie                                Koi Aap Sa
#
#                      director  \
# 100                       NaN
# 101  Chapman Way, Maclain Way
# 102               Jason Hehir
# 103                Yemi Amodu
# 104                       NaN
# ...

# %% [markdown]
# ## (loc method)

# %%
df.loc[500,"type"]
# Out:
# 'Movie'

# %% [markdown]
# ## Rename column

# %%
df.rename(columns={"title":"movie name","description":"summary"},inplace="true")

# %%
df.iloc[100:105]
# Out:
#     show_id     type                                movie name  \
# 100    s101  TV Show                   Tobot Galaxy Detectives
# 101    s102    Movie                    Untold: Breaking Point
# 102    s103  TV Show  Countdown: Inspiration4 Mission to Space
# 103    s104    Movie                            Shadow Parties
# 104    s105  TV Show                       Tayo the Little Bus
#
#                      director  \
# 100                       NaN
# 101  Chapman Way, Maclain Way
# 102               Jason Hehir
# 103                Yemi Amodu
# 104                       NaN
#
#                                                   cast        country  \
# 100  Austin Abell, Travis Turner, Cole Howard, Anna...            NaN
# 101                                                NaN  United States
# 102                                                NaN            NaN
# 103  Jide Kosoko, Omotola Jalade-Ekeinde, Yemi Blaq...            NaN
# ...

# %% [markdown]
# ## value count

# %%
df["type"].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
df["country"].value_counts()
# Out:
# country
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: count, Length: 748, dtype: int64

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### 5.2 clean numerical columns with characters

# %%
# df["engine"]=pd.to_numeric(
#    .astype(str)
#    .str.replace(r'[^0]','',regax=True)
#    .replace('',None),
#    error='coerce'
#)

# %% [markdown]
# #### parse date_added as datetime

# %%
df["date_added"]=pd.to_datetime(df["date_added"],
                                errors="coerce")

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# movie name              object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# summary                 object
# dtype: object

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
import pandas as pd

def categorize_rating(rating):
    if pd.isna(rating):
        return "Unknown"
    
    rating = str(rating).strip()

    # Handle wrong entries like durations
    if "min" in rating:
        return "Unknown"
    
    # Kids content
    if rating in ["TV-Y", "TV-Y7", "TV-Y7-FV", "G"]:
        return "Kids"
    
    # Family / General
    elif rating in ["TV-G", "PG", "TV-PG"]:
        return "Family"
    
    # Teens
    elif rating in ["PG-13", "TV-14"]:
        return "Teen"
    
    # Adults
    elif rating in ["R", "TV-MA", "NC-17"]:
        return "Adult"
    
    # Not Rated / Others
    elif rating in ["NR", "UR"]:
        return "Unrated"
    
    else:
        return "Unrated"

# %%
df["rating_category"] = df["rating"].apply(categorize_rating)

# %%
print(df["rating_category"].value_counts())
# Out:
# rating_category
# Adult      4009
# Teen       2650
# Family     1370
# Kids        688
# Unrated      83
# Unknown       7
# Name: count, dtype: int64

# %%
df
# Out:
#      show_id     type             movie name         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   show_id          8807 non-null   object
#  1   type             8807 non-null   object
#  2   movie name       8807 non-null   object
#  3   director         6173 non-null   object
#  4   cast             7982 non-null   object
#  5   country          7976 non-null   object
#  6   date_added       8797 non-null   datetime64[ns]
#  7   release_year     8807 non-null   int64
#  8   rating           8803 non-null   object
#  9   duration         8804 non-null   object
#  10  listed_in        8807 non-null   object
#  11  summary          8807 non-null   object
#  12  rating_category  8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 894.6+ KB

# %% [markdown]
# ### Handling missing values

# %%
df.isnull()
# Out:
#       show_id   type  movie name  director   cast  country  date_added  \
# 0       False  False       False     False   True    False       False
# 1       False  False       False      True  False    False       False
# 2       False  False       False     False  False     True       False
# 3       False  False       False      True   True     True       False
# 4       False  False       False      True  False    False       False
# ...       ...    ...         ...       ...    ...      ...         ...
# 8802    False  False       False     False  False    False       False
# 8803    False  False       False      True   True     True       False
# 8804    False  False       False     False  False    False       False
# 8805    False  False       False     False  False    False       False
# 8806    False  False       False     False  False    False       False
#
#       release_year  rating  duration  listed_in  summary  rating_category
# ...

# %%
df.isnull().sum()
# Out:
# show_id               0
# type                  0
# movie name            0
# director           2634
# cast                825
# country             831
# date_added           10
# release_year          0
# rating                4
# duration              3
# listed_in             0
# summary               0
# rating_category       0
# dtype: int64

# %% [markdown]
# ### how to fill missing values

# %%
df['director'].fillna("unknown",inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17028\2513338713.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['director'].fillna("unknown",inplace=True)

# %%
df['country'].fillna("unknown",inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17028\367023652.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna("unknown",inplace=True)

# %%
df['cast'].fillna("unknown",inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17028\2462058862.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cast'].fillna("unknown",inplace=True)

# %%
df.dropna(subset=["date_added","rating","duration"],inplace=True)

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# movie name         0
# director           0
# cast               0
# country            0
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# summary            0
# rating_category    0
# dtype: int64

# %%
df.shape
# Out:
# (8790, 13)

# %% [markdown]
# ### Handling duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# print("before:",df.shape)
# df=df.drop_duplicates()
# print("after:",df.shape)

# %% [markdown]
# ### Ensuring data cleaning

# %%
df.head(10)
# Out:
#   show_id     type                        movie name  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                        unknown
# 2                Julien Leclercq
# 3                        unknown
# 4                        unknown
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# movie name         0
# director           0
# cast               0
# country            0
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# summary            0
# rating_category    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'movie name', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in',
#        'summary', 'rating_category'],
#       dtype='object')

# %%
df.dtypes
# Out:
# show_id                    object
# type                       object
# movie name                 object
# director                   object
# cast                       object
# country                    object
# date_added         datetime64[ns]
# release_year                int64
# rating                     object
# duration                   object
# listed_in                  object
# summary                    object
# rating_category            object
# dtype: object

# %%
df.sample(10)
# Out:
#      show_id     type                                    movie name  \
# 8047   s8048    Movie                                  Socha Na Tha
# 4543   s4544    Movie                 Monty Python Conquers America
# 6176   s6177    Movie                                         Anwar
# 1021   s1022    Movie                                   Peepli Live
# 8557   s8558  TV Show                                 The West Wing
# 650     s651    Movie                          O Vendedor de Sonhos
# 3381   s3382  TV Show                                   The Untamed
# 2919   s2920    Movie                       Dragon Quest Your Story
# 8714   s8715    Movie     Welcome to Monster High: The Origin Story
# 1132   s1133    Movie  Seven Souls in the Skull Castle: Season Wind
#
#                                              director  \
# 8047                                       Imtiaz Ali
# 4543                                        Will Yapp
# ...

# %%
df.shape
# Out:
# (8790, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8790 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   show_id          8790 non-null   object
#  1   type             8790 non-null   object
#  2   movie name       8790 non-null   object
#  3   director         8790 non-null   object
#  4   cast             8790 non-null   object
#  5   country          8790 non-null   object
#  6   date_added       8790 non-null   datetime64[ns]
#  7   release_year     8790 non-null   int64
#  8   rating           8790 non-null   object
#  9   duration         8790 non-null   object
#  10  listed_in        8790 non-null   object
#  11  summary          8790 non-null   object
#  12  rating_category  8790 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(11)
# memory usage: 961.4+ KB

# %% [markdown]
# ### filtering the data -movie and tv show

# %%
movies=df[df['type']=='Movie']

# %%
movies
# Out:
#      show_id   type                        movie name  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
tv_shows=df[df['type']=='TV Show']

# %%
tv_shows
# Out:
#      show_id     type             movie name         director  \
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V          unknown
# 8796   s8797  TV Show             Yunus Emre          unknown
# 8797   s8798  TV Show              Zak Storm          unknown
# 8800   s8801  TV Show     Zindagi Gulzar Hai          unknown
# 8803   s8804  TV Show            Zombie Dumb          unknown
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %% [markdown]
# ### Save to file

# %%
df.to_csv("netflix_cleaned.csv",index=False)

# %%
movies.to_csv("movies.csv",index=False)

# %%
tv_shows.to_csv("tv_shows.csv",index=False)

# %% [markdown]
# ### Load new data

# %%
df_new=pd.read_csv("netflix_cleaned.csv")

# %%
df_new
# Out:
#      show_id     type             movie name         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          unknown
# 4         s5  TV Show           Kota Factory          unknown
# ...      ...      ...                    ...              ...
# 8785   s8803    Movie                 Zodiac    David Fincher
# 8786   s8804  TV Show            Zombie Dumb          unknown
# 8787   s8805    Movie             Zombieland  Ruben Fleischer
# 8788   s8806    Movie                   Zoom     Peter Hewitt
# 8789   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_new1=pd.read_csv("movies.csv")

# %%
df_new1
# Out:
#      show_id   type                        movie name  \
# 0         s1  Movie              Dick Johnson Is Dead
# 1         s7  Movie  My Little Pony: A New Generation
# 2         s8  Movie                           Sankofa
# 3        s10  Movie                      The Starling
# 4        s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 6121   s8802  Movie                           Zinzana
# 6122   s8803  Movie                            Zodiac
# 6123   s8805  Movie                        Zombieland
# 6124   s8806  Movie                              Zoom
# 6125   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 1     Robert Cullen, José Luis Ucha
# 2                      Haile Gerima
# 3                    Theodore Melfi
# 4               Christian Schwochow
# ...                             ...
# 6121                Majid Al Ansari
# ...

# %%
df_new2=pd.read_csv("tv_shows.csv")

# %%
df_new2
# Out:
#      show_id     type             movie name         director  \
# 0         s2  TV Show          Blood & Water          unknown
# 1         s3  TV Show              Ganglands  Julien Leclercq
# 2         s4  TV Show  Jailbirds New Orleans          unknown
# 3         s5  TV Show           Kota Factory          unknown
# 4         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 2659   s8796  TV Show        Yu-Gi-Oh! Arc-V          unknown
# 2660   s8797  TV Show             Yunus Emre          unknown
# 2661   s8798  TV Show              Zak Storm          unknown
# 2662   s8801  TV Show     Zindagi Gulzar Hai          unknown
# 2663   s8804  TV Show            Zombie Dumb          unknown
#
#                                                    cast  \
# 0     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 1     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %% [markdown]
# ### summary statistics

# %% [markdown]
# ### Average(mean)

# %%
print("release_year  -",df_new["release_year"].mean())
# Out:
# release_year  - 2014.183162684869

# %% [markdown]
# ### Median

# %%
print("release_year  -",df_new["release_year"].median())
# Out:
# release_year  - 2017.0

# %% [markdown]
# ### Mode

# %%
df_new["release_year"].mode()
# Out:
# 0    2018
# Name: release_year, dtype: int64

# %%
print("release_year  -",df_new["release_year"].mode())
# Out:
# release_year  - 0    2018
# Name: release_year, dtype: int64

# %% [markdown]
# ### Standard deviation

# %%
print("release_year  -",df_new["release_year"].std())
# Out:
# release_year  - 8.82546602834746

# %% [markdown]
# ###

# %%
df_new.select_dtypes(include='number').mean()
# Out:
# release_year    2014.183163
# dtype: float64

# %%
df_new.select_dtypes(include='number').median()
# Out:
# release_year    2017.0
# dtype: float64

# %%
df_new.select_dtypes(include='object').mode()
# Out:
#      show_id   type                     movie name director     cast  \
# 0         s1  Movie                         #Alive  unknown  unknown
# 1        s10    NaN  #AnneFrank - Parallel Stories      NaN      NaN
# 2       s100    NaN              #FriendButMarried      NaN      NaN
# 3      s1000    NaN            #FriendButMarried 2      NaN      NaN
# 4      s1001    NaN                          #Roxy      NaN      NaN
# ...      ...    ...                            ...      ...      ...
# 8785    s995    NaN                       忍者ハットリくん      NaN      NaN
# 8786    s996    NaN                           海的儿子      NaN      NaN
# 8787    s997    NaN                           마녀사냥      NaN      NaN
# 8788    s998    NaN                        반드시 잡는다      NaN      NaN
# 8789    s999    NaN            최강전사 미니특공대 : 영웅의 탄생      NaN      NaN
#
#             country  date_added rating  duration  \
# 0     United States  2020-01-01  TV-MA  1 Season
# ...

# %%
df_new.select_dtypes(include='number').std()
# Out:
# release_year    8.825466
# dtype: float64

# %%
df_new.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# - the data set contains 8790 entries
# - the average release year is 2014
# - the standard deviation is 8.825
# - the oldest content dates back to 1925
# - 25% of the content was released before 2013
# - The median release year is 2017
# - 75% of the content was released before 2019
# - The latest content is from 2021

# %%
df_new.describe(include='object')
# Out:
#        show_id   type            movie name director     cast        country  \
# count     8790   8790                  8790     8790     8790           8790
# unique    8790      2                  8790     4527     7679            749
# top         s1  Movie  Dick Johnson Is Dead  unknown  unknown  United States
# freq         1   6126                     1     2621      825           2809
#
#         date_added rating  duration                     listed_in  \
# count         8790   8790      8790                          8790
# unique        1713     14       220                           513
# top     2020-01-01  TV-MA  1 Season  Dramas, International Movies
# freq           110   3205      1791                           362
#
#                                                   summary rating_category
# count                                                8790            8790
# unique                                               8758               5
# ...

# %% [markdown]
# - total 8790 entries,means no missing values
# - 2 unique values are movie and tv shows,dataset is heavily movie-dominate
# - every titles are unique
# - 4527 directors are unique ,the most of them are unknown(2621)
# - 7679 cast are unique,most of them are unknown(825)
# - most content dominated by the united states
# - 110 shows were released on 01/01/2020
# - majority content TV-MA
# - drama & international movies are the majority of the genre
# - most target on adult audience

# %%
df_new1.describe(include='object')
# Out:
#        show_id   type            movie name director     cast        country  \
# count     6126   6126                  6126     6126     6126           6126
# unique    6126      1                  6126     4353     5444            652
# top         s1  Movie  Dick Johnson Is Dead  unknown  unknown  United States
# freq         1   6126                     1      187      475           2055
#
#         date_added rating duration                     listed_in  \
# count         6126   6126     6126                          6126
# unique        1531     14      205                           278
# top     2020-01-01  TV-MA   90 min  Dramas, International Movies
# freq            97   2062      152                           362
#
#                                                   summary rating_category
# count                                                6126            6126
# unique                                               6100               5
# ...

# %% [markdown]
# - Total 6126 entries,means no missing
# - only movies are  in the dstaset
# - 4353 directors are unique,187 directors are unknown
# - 475 cast are unknown
# - most of the  movies dominated by united status
# - 97 movies are released on 01/01/2020
# - majority content is TV-MA
# - dramas & international Movies are the majority of the genre
# - 205 movies are unique duration,152 movies are 90 min duration

# %%
df_new2.describe(include='object')
# Out:
#        show_id     type     movie name director     cast        country  \
# count     2664     2664           2664     2664     2664           2664
# unique    2664        1           2664      223     2272            197
# top         s2  TV Show  Blood & Water  unknown  unknown  United States
# freq         1     2664              1     2434      350            754
#
#         date_added rating  duration listed_in  \
# count         2664   2664      2664      2664
# unique        1012      9        15       235
# top     2021-07-06  TV-MA  1 Season  Kids' TV
# freq            31   1143      1791       219
#
#                                                   summary rating_category
# count                                                2664            2664
# unique                                               2660               5
# top     As a psychology professor faces Alzheimer's, h...           Adult
# freq                                                    2            1145

# %% [markdown]
# - total 2664 entries,means no missing
# - only tv show are in the data set
# - 223 directors are unique,2434 directors are unknown
# - 350 cast are unknown
# - most of the tv shows dominated by united states
# - 31 movies are released on 06/07/2021
# - majority content is TV-MA
# - 15 tv shows are unique,1791 tv shows are 1 season
# - kid's tv are the majority of the genre

# %% [markdown]
# ## Data visualization

# %% [markdown]
# ### Histogram
#
# - Distribution of continous numerical data

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(4,6))      
sns.histplot(data=df_new,x="release_year",bins=50,color="purple")
plt.title("Distribution of Release Year")
plt.xlabel("Release Year")
plt.show()

# %% [markdown]
# - the histogram shows the distribution of release year
# - A huge majority of the releases happened in the last 10-15 years.
# - There are very few releases from before the year 2000.
# - The no.of releases started growing very fast after 2010.
# - 2018 and 2019 were the biggest year of releases.
# - The numbers drop suddenly after 2019
# - The distribution is strongly left-skewed
